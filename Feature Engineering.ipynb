# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import RandomizedSearchCV, cross_val_score, GridSearchCV

# %%
rand_state = 19

# %%
gdd_data = pd.read_csv('/Users/coleromanyk/Downloads/corn_gdd.csv')

# %%
gdd_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15651 entries, 0 to 15650
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             15651 non-null  object
#  1   Month            15650 non-null  float64
#  2   Day              15650 non-null  float64
#  3   Accumulated GDD  15650 non-null  float64
# dtypes: float64(3), object(1)
# memory usage: 489.2+ KB

# %%
gdd_data.Year.unique()
# Out:
# array(['Average', 'Median', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019', '2020', '2021', "''"], dtype=object)

# %%
non_year = ['Average', 'Median', "''"]

# %%
gdd_data = gdd_data[~gdd_data.Year.isin(non_year)]

# %%
gdd_data.Year = pd.to_numeric(gdd_data.Year)

# %%
year_range = list(range(1990, 2018))

# %%
gdd_filter = gdd_data[(gdd_data['Year'].isin(year_range)) & \
                      (gdd_data['Month'] == gdd_data.Month.max()) & (gdd_data['Day'] == gdd_data.Day.max())]

# %%
gdd = gdd_filter.drop(['Month', 'Day'], axis=1)

# %%
hold_out = pd.read_csv('/Users/coleromanyk/Documents/GitHub/Capstone 2/hold_out_data300.csv')
train_data= pd.read_csv('/Users/coleromanyk/Documents/GitHub/Capstone 2/SMOTE300_data.csv')

# %%
hold_out = hold_out.merge(gdd, how='left')
train_data = train_data.merge(gdd, how='left')

# %%
train_data.head()
# Out:
#    Year  Per Acre Emissions      N     P  Potash  IN Corn Yield per Acre  \
# 0  1993            2.860590  134.0  68.0   114.0                     132
# 1  2007            3.367331  149.0  69.0   124.0                     154
# 2  1999            3.341237  154.0  56.0   116.0                     132
# 3  2001            2.929382  140.0  66.0   121.0                     156
# 4  1990            3.306718  139.0  75.0   111.0                     129
#
#    Precipitation  Average Temperature  IN No Till Corn (Thousands of acres)  \
# 0          50.78                 52.0                              1211.769
# 1          36.75                 55.0                              1542.152
# 2          32.40                 54.5                              1044.103
# 3          41.91                 54.2                              1092.997
# 4          50.44                 54.4                               479.255
#
#    IN Con Till Corn (Thousands of acres)  \
# 0                               1536.438
# 1                               2202.153
# 2                               1548.732
# 3                               1532.988
# 4                                824.200
#
#    IN Corn Cover Crop (Thousands of acres)  Conventional Till  efficiency  \
# 0                                      0.0           2651.793   46.144325
# 1                                      0.0           2625.695   45.733543
# 2                                      0.0           3077.165   39.506327
# 3                                      0.0           3044.015   53.253548
# 4                                      0.0           4146.545   39.011486
#
#    Accumulated GDD
# 0           3231.0
# 1           3778.0
# 2           3680.0
# 3           3607.0
# 4           3310.0

# %%
X_train = train_data.drop(['IN Corn Yield per Acre'], axis=1)
y_train = train_data['efficiency']

# %%
X_test = hold_out.drop(['efficiency', 'IN Corn Yield per Acre'], axis=1)
y_test = hold_out['efficiency']

# %%
# X_train = train_data.drop(['Per Acre Emissions', 'efficiency', 'IN Corn Yield per Acre'], axis=1)
# y_train = train_data['efficiency']

# %%
# X_test = hold_out.drop(['Per Acre Emissions', 'efficiency', 'IN Corn Yield per Acre'], axis=1)
# y_test = hold_out['efficiency']

# %%
X_train[X_train.N == X_train.N.max()]
# Out:
#      Year  Per Acre Emissions      N     P  Potash  Precipitation  \
# 16   2010            3.420192  178.0  69.0   119.0          33.89
# 96   2010            3.420192  178.0  69.0   119.0          33.89
# 108  2010            3.420192  178.0  69.0   119.0          33.89
# 112  2010            3.420192  178.0  69.0   119.0          33.89
# 182  2010            3.420192  178.0  69.0   119.0          33.89
# 250  2010            3.420192  178.0  69.0   119.0          33.89
# 293  2010            3.420192  178.0  69.0   119.0          33.89
#
#      Average Temperature  IN No Till Corn (Thousands of acres)  \
# 16                  54.6                               1270.35
# 96                  54.6                               1270.35
# 108                 54.6                               1270.35
# 112                 54.6                               1270.35
# 182                 54.6                               1270.35
# 250                 54.6                               1270.35
# 293                 54.6                               1270.35
#
#      IN Con Till Corn (Thousands of acres)  \
# 16                                  2146.1
# 96                                  2146.1
# 108                                 2146.1
# 112                                 2146.1
# 182                                 2146.1
# 250                                 2146.1
# 293                                 2146.1
#
#      IN Corn Cover Crop (Thousands of acres)  Conventional Till  efficiency  \
# 16                                       0.0            2303.55   45.903862
# 96                                       0.0            2303.55   45.903862
# 108                                      0.0            2303.55   45.903862
# 112                                      0.0            2303.55   45.903862
# 182                                      0.0            2303.55   45.903862
# 250                                      0.0            2303.55   45.903862
# 293                                      0.0            2303.55   45.903862
#
#      Accumulated GDD
# 16            3845.0
# 96            3845.0
# 108           3845.0
# 112           3845.0
# 182           3845.0
# 250           3845.0
# 293           3845.0

# %%
# X_train['total_acres'] = X_train['IN No Till Corn (Thousands of acres)']+\
# X_train['IN Con Till Corn (Thousands of acres)']+X_train['Conventional Till']

# %%
# X_train['full_till_ratio'] = X_train['Conventional Till'] / X_train['total_acres']

# %%
# X_train['conservation_till_ratio'] = 1 - X_train['full_till_ratio']

# %%
# X_train['cover_crop_ratio'] = X_train['IN Corn Cover Crop (Thousands of acres)'] / X_train['total_acres']

# %%
dfs = [X_train, X_test]
for df in dfs:
    df['total_acres'] = df['IN No Till Corn (Thousands of acres)']+\
    df['IN Con Till Corn (Thousands of acres)']+df['Conventional Till']
    
    df['full_till_ratio'] = df['Conventional Till'] / df['total_acres']
    
    df['conservation_till_ratio'] = 1 - df['full_till_ratio']
    
    df['cover_crop_ratio'] = df['IN Corn Cover Crop (Thousands of acres)'] / df['total_acres']

# %%
X_train['temp_variation'] = X_train['Average Temperature'] - X_train['Average Temperature'].mean()

# %%
X_train['precip_variation'] = X_train['Precipitation'] - X_train['Precipitation'].mean()

# %%
X_train['N_variation'] = X_train['N'] - X_train['N'].mean()

# %%
X_train[(X_train['Per Acre Emissions'] > 3.7) & (X_train['Per Acre Emissions'] < 4.3) & (X_train['IN Corn Cover Crop (Thousands of acres)'] > 0)]
# Out:
#      Year  Per Acre Emissions           N          P      Potash  \
# 13   2012            3.948001  160.000000  75.000000  127.000000
# 25   2014            3.948001  162.603244  73.603244  114.157827
# 81   2012            3.948001  160.000000  75.000000  127.000000
# 82   2014            3.948001  162.603244  73.603244  114.157827
# 88   2014            3.948001  162.603244  73.603244  114.157827
# 122  2012            3.948001  160.000000  75.000000  127.000000
# 148  2014            3.948001  162.603244  73.603244  114.157827
# 196  2014            3.948001  162.603244  73.603244  114.157827
# 222  2014            3.948001  162.603244  73.603244  114.157827
# 251  2012            3.948001  160.000000  75.000000  127.000000
# 263  2012            3.948001  160.000000  75.000000  127.000000
#
#      Precipitation  Average Temperature  IN No Till Corn (Thousands of acres)  \
# 13        38.04000            56.800000                           1281.500000
# 25        45.95413            54.390706                           1333.669748
# 81        38.04000            56.800000                           1281.500000
# 82        45.95413            54.390706                           1333.669748
# 88        45.95413            54.390706                           1333.669748
# 122       38.04000            56.800000                           1281.500000
# 148       45.95413            54.390706                           1333.669748
# 196       45.95413            54.390706                           1333.669748
# 222       45.95413            54.390706                           1333.669748
# 251       38.04000            56.800000                           1281.500000
# 263       38.04000            56.800000                           1281.500000
#
#      IN Con Till Corn (Thousands of acres)  \
# 13                             2195.550000
# 25                             2132.130037
# 81                             2195.550000
# 82                             2132.130037
# 88                             2132.130037
# 122                            2195.550000
# 148                            2132.130037
# 196                            2132.130037
# 222                            2132.130037
# 251                            2195.550000
# 263                            2195.550000
#
#      IN Corn Cover Crop (Thousands of acres)  Conventional Till  efficiency  \
# 13                                139.650000        2552.950000   25.075985
# 25                                380.858499        2147.032338   58.908347
# 81                                139.650000        2552.950000   25.075985
# 82                                380.858499        2147.032338   58.908347
# 88                                380.858499        2147.032338   58.908347
# 122                               139.650000        2552.950000   25.075985
# 148                               380.858499        2147.032338   58.908347
# 196                               380.858499        2147.032338   58.908347
# 222                               380.858499        2147.032338   58.908347
# 251                               139.650000        2552.950000   25.075985
# 263                               139.650000        2552.950000   25.075985
#
#      Accumulated GDD  total_acres  full_till_ratio  conservation_till_ratio  \
# 13            3539.0  6030.000000         0.423375                 0.576625
# 25            3383.0  5612.832122         0.382522                 0.617478
# 81            3539.0  6030.000000         0.423375                 0.576625
# 82            3383.0  5612.832122         0.382522                 0.617478
# 88            3383.0  5612.832122         0.382522                 0.617478
# 122           3539.0  6030.000000         0.423375                 0.576625
# 148           3383.0  5612.832122         0.382522                 0.617478
# 196           3383.0  5612.832122         0.382522                 0.617478
# 222           3383.0  5612.832122         0.382522                 0.617478
# 251           3539.0  6030.000000         0.423375                 0.576625
# 263           3539.0  6030.000000         0.423375                 0.576625
#
#      cover_crop_ratio  temp_variation  precip_variation  N_variation
# 13           0.023159        2.715336         -6.953009     6.442958
# 25           0.067855        0.306042          0.961121     9.046202
# 81           0.023159        2.715336         -6.953009     6.442958
# 82           0.067855        0.306042          0.961121     9.046202
# 88           0.067855        0.306042          0.961121     9.046202
# 122          0.023159        2.715336         -6.953009     6.442958
# 148          0.067855        0.306042          0.961121     9.046202
# 196          0.067855        0.306042          0.961121     9.046202
# 222          0.067855        0.306042          0.961121     9.046202
# 251          0.023159        2.715336         -6.953009     6.442958
# 263          0.023159        2.715336         -6.953009     6.442958

# %%
X_train[(X_train['N'] > 175) & (X_train['IN Corn Cover Crop (Thousands of acres)'] == 0)]
# Out:
#      Year  Per Acre Emissions      N     P  Potash  Precipitation  \
# 16   2010            3.420192  178.0  69.0   119.0          33.89
# 96   2010            3.420192  178.0  69.0   119.0          33.89
# 108  2010            3.420192  178.0  69.0   119.0          33.89
# 112  2010            3.420192  178.0  69.0   119.0          33.89
# 182  2010            3.420192  178.0  69.0   119.0          33.89
# 250  2010            3.420192  178.0  69.0   119.0          33.89
# 293  2010            3.420192  178.0  69.0   119.0          33.89
#
#      Average Temperature  IN No Till Corn (Thousands of acres)  \
# 16                  54.6                               1270.35
# 96                  54.6                               1270.35
# 108                 54.6                               1270.35
# 112                 54.6                               1270.35
# 182                 54.6                               1270.35
# 250                 54.6                               1270.35
# 293                 54.6                               1270.35
#
#      IN Con Till Corn (Thousands of acres)  \
# 16                                  2146.1
# 96                                  2146.1
# 108                                 2146.1
# 112                                 2146.1
# 182                                 2146.1
# 250                                 2146.1
# 293                                 2146.1
#
#      IN Corn Cover Crop (Thousands of acres)  Conventional Till  efficiency  \
# 16                                       0.0            2303.55   45.903862
# 96                                       0.0            2303.55   45.903862
# 108                                      0.0            2303.55   45.903862
# 112                                      0.0            2303.55   45.903862
# 182                                      0.0            2303.55   45.903862
# 250                                      0.0            2303.55   45.903862
# 293                                      0.0            2303.55   45.903862
#
#      Accumulated GDD  total_acres  full_till_ratio  conservation_till_ratio  \
# 16            3845.0       5720.0         0.402719                 0.597281
# 96            3845.0       5720.0         0.402719                 0.597281
# 108           3845.0       5720.0         0.402719                 0.597281
# 112           3845.0       5720.0         0.402719                 0.597281
# 182           3845.0       5720.0         0.402719                 0.597281
# 250           3845.0       5720.0         0.402719                 0.597281
# 293           3845.0       5720.0         0.402719                 0.597281
#
#      cover_crop_ratio  temp_variation  precip_variation  N_variation
# 16                0.0        0.515336        -11.103009    24.442958
# 96                0.0        0.515336        -11.103009    24.442958
# 108               0.0        0.515336        -11.103009    24.442958
# 112               0.0        0.515336        -11.103009    24.442958
# 182               0.0        0.515336        -11.103009    24.442958
# 250               0.0        0.515336        -11.103009    24.442958
# 293               0.0        0.515336        -11.103009    24.442958

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300 entries, 0 to 299
# Data columns (total 20 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Year                                     300 non-null    int64
#  1   Per Acre Emissions                       300 non-null    float64
#  2   N                                        300 non-null    float64
#  3   P                                        300 non-null    float64
#  4   Potash                                   300 non-null    float64
#  5   Precipitation                            300 non-null    float64
#  6   Average Temperature                      300 non-null    float64
#  7   IN No Till Corn (Thousands of acres)     300 non-null    float64
#  8   IN Con Till Corn (Thousands of acres)    300 non-null    float64
#  9   IN Corn Cover Crop (Thousands of acres)  300 non-null    float64
#  10  Conventional Till                        300 non-null    float64
#  11  efficiency                               300 non-null    float64
#  12  Accumulated GDD                          300 non-null    float64
#  13  total_acres                              300 non-null    float64
#  14  full_till_ratio                          300 non-null    float64
#  15  conservation_till_ratio                  300 non-null    float64
#  16  cover_crop_ratio                         300 non-null    float64
#  17  temp_variation                           300 non-null    float64
#  18  precip_variation                         300 non-null    float64
#  19  N_variation                              300 non-null    float64
# dtypes: float64(19), int64(1)
# memory usage: 49.2 KB
